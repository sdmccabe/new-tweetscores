# %%
library(tidyverse)
library(Matrix)
library(patchwork)
# Out:
# Warning message:
# “replacing previous import ‘vctrs::data_frame’ by ‘tibble::data_frame’ when loading ‘dplyr’”
# ── Attaching packages ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.0     ✔ dplyr   1.0.1
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack

# %%
options(repr.plot.width=12, repr.plot.height=6.75)

# %%
vf <- read_tsv("../data/thetas.tsv", col_types = 'cnfnnnnn')
# Out:
# Warning message:
# “4 parsing failures.
#    row            col expected actual                 file
# 321235 theta          a number    NaN '../data/thetas.tsv'
# 321235 scaled_theta   a number    NaN '../data/thetas.tsv'
# 321235 theta_2        a number    NaN '../data/thetas.tsv'
# 321235 scaled_theta_2 a number    NaN '../data/thetas.tsv'
# ”

# %%
vf <- filter(vf, follows  > 5)

# %%
ggplot(vf, aes(x=scaled_theta, fill=party)) + geom_density() + facet_wrap(vars(party)) + scale_fill_manual(values=c("firebrick", "goldenrod", "dodgerblue")) + theme_bw()
# Out:
# plot without title

# %%
ggplot(vf, aes(x=scaled_theta_2, fill=party)) + geom_density() + facet_wrap(vars(party)) + scale_fill_manual(values=c("firebrick", "goldenrod", "dodgerblue")) + theme_bw()
# Out:
# plot without title

# %%
ggplot(vf, aes(y=follows, x=scaled_theta, color=party)) + geom_point(alpha=0.3) + scale_color_manual(values=c("firebrick", "goldenrod", "dodgerblue")) + theme_bw()
# Out:
# plot without title

# %%
ggplot(vf, aes(y=follows, x=scaled_theta_2, color=party)) + geom_point(alpha=0.3) + scale_color_manual(values=c("firebrick", "goldenrod", "dodgerblue")) + theme_bw()
# Out:
# plot without title

# %%
ggplot(vf, aes(x=scaled_theta, y=scaled_theta_2, color=party)) + geom_point(alpha=0.3) + scale_color_manual(values=c("firebrick", "goldenrod", "dodgerblue")) + theme_bw()
# Out:
# plot without title

# %%
p1<- ggplot(vf, aes(x=scaled_theta, fill=party)) + geom_density(alpha=0.3) + scale_fill_manual(values=c("firebrick", "goldenrod", "dodgerblue")) + theme_bw()
p2<- ggplot(vf, aes(x=scaled_theta_2, fill=party)) + geom_density(alpha=0.3) + scale_fill_manual(values=c("firebrick", "goldenrod", "dodgerblue")) + theme_bw()

p1+p2
# Out:
# plot without title

# %%
cor(vf$tsmart_partisan_score, vf$scaled_theta, use = "pairwise.complete.obs")
# Out:
# [1] -0.554981

# %%
ggplot(vf %>% filter(follows > 20), aes(x=tsmart_partisan_score, scaled_theta)) + geom_point(alpha=0.05) + geom_smooth() + theme_bw()
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
phi = read_tsv("../data/elites_combined_with_phi.tsv", col_types=c("ccciiiiiiiiinnnc"))
# Out:
# Warning message:
# “6 parsing failures.
# row   col expected actual                                   file
# 870 phi   a number    NaN '../data/elites_combined_with_phi.tsv'
# 870 phi_2 a number    NaN '../data/elites_combined_with_phi.tsv'
# 913 phi   a number    NaN '../data/elites_combined_with_phi.tsv'
# 913 phi_2 a number    NaN '../data/elites_combined_with_phi.tsv'
# 920 phi   a number    NaN '../data/elites_combined_with_phi.tsv'
# ... ..... ........ ...... ......................................
# See problems(...) for more details.
# ”
